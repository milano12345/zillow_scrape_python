# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import sys
import time
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext

#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

#add headers in case you use chromedriver (captchas are no fun); namely used for chromedriver
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

#create url variables for each zillow page
with requests.Session() as s:
    city = 'miami/' #*****change this city to what you want!!!!*****
    
    url = 'https://www.zillow.com/homes/for_sale/'+city
    url2 = 'https://www.zillow.com/homes/for_sale/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_sale/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_sale/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_sale/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_sale/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_sale/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_sale/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_sale/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_sale/'+city+'/10_p/'


    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

# page_links = [soup, soup1, soup2, soup3, soup4, soup5, soup6, soup7, soup8, soup9]

#create the first two dataframes
df = pd.DataFrame()
df1 = pd.DataFrame()

#all for loops are pulling the specified variable using beautiful soup and inserting into said variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
#     print(href)
    if href == None:
        addresses = None
#         addresses = 'zillow doesnt like this piece of code!'
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
#     print(addresses)
#     addresses = addresses.get_text()
#     addresses = href.find_all(href=True)
#     addresses = href.find('address class')
#     addresses.extract()
#     print(addresses)
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

df['links'] = urls
df['links'] = df['links'].astype('str')

#remove html tags
# df['links'] = df['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup1.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup1.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup1.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup1.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup1.find_all (class_= 'list-card-link')
#     zestimate1 = soup1.find_all (class_= 'Text-c11n-8-38-0__aiai24-0 jtMauM')

    #create dataframe columns out of variables
    df1['prices'] = price1
    df1['address'] = address1
    df1['beds'] = beds
#     df1['zestimate'] = zestimate1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df1['links'] = urls
df1['links'] = df1['links'].astype('str')

#remove html tags
# df1['links'] = df1['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df1['links'] = df1['links'].replace('" tabindex="0"></a>', ' ', regex=True)

#append first two dataframes
df = df.append(df1, ignore_index = True) 

#create empty dataframes
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()

for i in soup2:
    soup = soup2
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df2['prices'] = price
    df2['address'] = address
    df2['beds'] = beds

time.sleep(3.2)    

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup2.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df2['links'] = urls
df2['links'] = df2['links'].astype('str')

#remove html tags
# df2['links'] = df2['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df2['links'] = df2['links'].replace('" tabindex="0"></a>', ' ', regex=True)

#append n df
# df = df.append(df2, ignore_index = True) 
# display(df)
# time.sleep(3.1)

for i in soup3:
    soup = soup3
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df3['prices'] = price1
    df3['address'] = address1
    df3['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup3.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df3['links'] = urls
df3['links'] = df3['links'].astype('str')

#remove html tags
# df3['links'] = df3['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df3['links'] = df3['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup4:
    soup = soup4
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df4['prices'] = price1
    df4['address'] = address1
    df4['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup4.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df4['links'] = urls
df4['links'] = df4['links'].astype('str')

#remove html tags
# df4['links'] = df4['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df4['links'] = df4['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup5:
    soup = soup5
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df5['prices'] = price1
    df5['address'] = address1
    df5['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup5.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df5['links'] = urls
df5['links'] = df5['links'].astype('str')

#remove html tags
# df5['links'] = df5['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df5['links'] = df5['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup6:
    soup = soup6
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df6['prices'] = price1
    df6['address'] = address1
    df6['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup6.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

time.sleep(3)

#import urls into a links column
df6['links'] = urls
df6['links'] = df6['links'].astype('str')

#remove html tags
# df6['links'] = df6['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df6['links'] = df6['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup7:
    soup = soup7
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df7['prices'] = price1
    df7['address'] = address1
    df7['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup7.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df7['links'] = urls
df7['links'] = df7['links'].astype('str')

#remove html tags
# df7['links'] = df7['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df7['links'] = df7['links'].replace('" tabindex="0"></a>', ' ', regex=True)
    
for i in soup8:
    soup = soup8
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df8['prices'] = price1
    df8['address'] = address1
    df8['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup8.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df8['links'] = urls
df8['links'] = df8['links'].astype('str')

#remove html tags
# df8['links'] = df8['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df8['links'] = df8['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup9:
    soup = soup9
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df9['prices'] = price1
    df9['address'] = address1
    df9['beds'] = beds
#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup9.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df9['links'] = urls
df9['links'] = df9['links'].astype('str')

#remove html tags
# df9['links'] = df9['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df9['links'] = df9['links'].replace('" tabindex="0"></a>', ' ', regex=True)

df = df.append(df2, ignore_index = True) 
df = df.append(df3, ignore_index = True) 
df = df.append(df4, ignore_index = True) 
df = df.append(df5, ignore_index = True) 
df = df.append(df6, ignore_index = True) 
df = df.append(df7, ignore_index = True) 
df = df.append(df8, ignore_index = True) 
df = df.append(df9, ignore_index = True)

#convert columns to str
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')

#remove html tags
df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df['prices'] = df['prices'].str.replace(r'\D', '')

#remove html tags from beds column 
df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)
df['beds'] = df['beds'].replace('<ul class="list-card-details"><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->ba</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bd</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace(' abbr></li><li class="">', '|', regex=True)
df['beds'] = df['beds'].replace('Studio</li><li>', '0 ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->ba</', ' ', regex=True)
df['beds'] = df['beds'].replace(' abbr></li><li class="">', '|', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">- Condo for sale</li></ul>', ' ', regex=True)

df.columns = ['prices','address','bed_bath_sqft','links']
#split beds column into beds, bath and sq_feet
# df[['beds','baths','sq_feet']] = df.beds.str.split(expand=True)
# df[['baths']] = df.beds.str.split('|',expand=True)
# df[['sq_feet']] = df.baths.str.split('|',expand=True)

#remove commas from sq_feet and convert to float
df.replace(',','', regex=True, inplace=True)

#drop nulls
df = df[(df['prices'] != '') & (df['prices']!= ' ')]

#convert column to float
df['prices'] = df['prices'].astype('float')
# d['sq_feet'] = df['sq_feet'].astype('float')

#remove spaces from link column
# df['links'] = df.links.str.replace(' ','')

#display
display(df.head())

print('The column datatypes are:')
print(df.dtypes)
print('The dataframe shape is:', df.shape)
print('url', url_links)


#rearrange the columns
# df = df[['prices', 'address', 'links', 'beds', 'baths', 'sq_feet']]

# df

#calculate the zestimate and insert into a dataframe
zillow_zestimate = []
for link in url_links:
    print('link', link)
    print('soup', soup)
    
    r = s.get(link, headers=req_headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    home_value = soup.select_one('h4:contains("Home value")')
    if not home_value:
        home_value = soup.select_one('.zestimate').text.split()[-1]
    else:
        home_value = home_value.find_next('p').get_text(strip=True)
    zillow_zestimate.append(home_value)

cols=['zestimate']
zestimate_result = pd.DataFrame(zillow_zestimate, columns=cols)
# zestimate_result

#convert zestimate column to float, and remove , and $
zestimate_result['zestimate'] = zestimate_result['zestimate'].str.replace('$','')
zestimate_result['zestimate'] = zestimate_result['zestimate'].str.replace('/mo','')
zestimate_result['zestimate'] = zestimate_result['zestimate'].str.replace(',','')

#covert rows with non zestimate to 0
def non_zestimate(zestimate_result):
    if len(zestimate_result['zestimate']) > 20:
        return '0'
    elif len(zestimate_result['zestimate']) < 5:
        return '0'
    else:
        return zestimate_result['zestimate']

zestimate_result['zestimate'] = zestimate_result.apply(non_zestimate,axis=1)

# zestimate_result

#concat zestimate dataframe and original df
df = pd.concat([df, zestimate_result], axis=1)
df['zestimate'] = df['zestimate'].astype('float')

#create best deal column and sort by best_deal
df ['best_deal'] = df['prices'] - df['zestimate']
df = df.sort_values(by='best_deal')

df
# Out:
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:162: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:478: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:479: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df3, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:480: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df4, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:481: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df5, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:482: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df6, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:483: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df7, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:484: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df8, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:485: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df9, ignore_index = True)
# C:\Users\dmila\AppData\Local\Temp\ipykernel_7788\280763985.py:497: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')
#      prices                              address                                      bed_bath_sqft                              links
# 0  789900.0   12848 SW 136th Ter Miami FL 33186                                           4|3|2046   12848 SW 136th Ter Miami FL 33186
# 1  390000.0    10889 SW 88th Ter Miami FL 33176    3|3|1593<abbr class="list-card-label"> <!-- -...   10889 SW 88th Ter Miami FL 33176
# 2   54900.0      1863 NW 45th St Miami FL 33142    3|1|912<abbr class="list-card-label"> <!-- --...     1863 NW 45th St Miami FL 33142
# 3  549000.0   14642 SW 145th Ter Miami FL 33186                                           4|3|2081   14642 SW 145th Ter Miami FL 33186
# 4  425000.0      6731 SW 5th Ter Miami FL 33144                                           3|2|1654      6731 SW 5th Ter Miami FL 33144
# The column datatypes are:
# prices           float64
# address           object
# bed_bath_sqft     object
# links             object
# dtype: object
# The dataframe shape is: (90, 4)
# url ['https://www.zillow.com/homes/for_sale/miami/', 'https://www.zillow.com/homes/for_sale/miami//2_p/', 'https://www.zillow.com/homes/for_sale/miami//3_p/', 'https://www.zillow.com/homes/for_sale/miami//4_p/', 'https://www.zillow.com/homes/for_sale/miami//5_p/', 'https://www.zillow.com/homes/for_sale/miami//6_p/', 'https://www.zillow.com/homes/for_sale/miami//7_p/', 'https://www.zillow.com/homes/for_sale/miami//8_p/', 'https://www.zillow.com/homes/for_sale/miami//9_p/', 'https://www.zillow.com/homes/for_sale/miami//10_p/']
# link https://www.zillow.com/homes/for_sale/miami/
# soup <!DOCTYPE html>
# <html class="no-js zsg-theme-modernized null" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#">
# <head>
# <title>Miami Real Estate - Miami FL Homes For Sale | Zillow</title><meta content="Zillow has 2,348 homes for sale in Miami FL. View listing photos, review sales history, and use our detailed real estate filters to find the perfect place." name="description"/><meta content="Zillow, Inc." name="author"/><meta content="Copyright (c) 2006-2022 Zillow, Inc." name="Copyright"/><script>
#         if (typeof Object.assign === 'function') {
#             window.appInfo = Object.assign(
#                 typeof window.appInfo === 'object' ? window.appInfo : {},
#                 {"@zillow/page-frame-content":"cc350e56"}
#             );
#         }
#     </script><script>
#         window.CLIENT_PROFILER_CONFIG = window.CLIENT_PROFILER_CONFIG || {
#             staticDimensions: {
#                 ABDecisionToken: "CsIikOBC0Vbw",
#             },
#         };
#     </script><script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');</script><script>window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#     ga("create","UA-21174015-56", "auto", {allowLinker:true});
#     ga('set','dimension1', '666c37a240334183ad2a41da562008d8');
#     ga('set','dimension191', '');
#     /* Queue for Global UA Object */
#     (function(w,n){w[n]=w[n]||function(){(w[n].q=w[n].q||[]).push(arguments)}})(window, 'ua');
#     ua('set','dimension1', '666c37a240334183ad2a41da562008d8');
#     ua('set','dimension191', '');
#     ua('set', {"dimension46":"AB_DASHBOARD_AA_TEST.CONTROL","dimension185":"AIPERS_COLLECTIONS_UPDATES_TAB.MODEL_C_1","dimension50":"ARCS_ABAD_PHX.ON","dimension44":"ARCS_CLICK_TO_CALL_TRACKING.CONTROL","dimension56":"ARCS_PA_ZHL_LEAD.T1_OPAQUE_LIGHTBOX_ONLY_ABAD_ABC_ONLY","dimension39":"ARCS_TOUR_UPGRADE_V1.ARCS_TOUR_UPGRADE_PLAIN","dimension49":"AR_BUYER_INITIATED_RELATIONSHIP_UI.CONTROL","dimension64":"DXP_RTB_LINKING.CONTROL","dimension57":"HDP_HFF_ACCORDION.CONTROL","dimension58":"HDP_SELLING_SOON_MSG.MOBILE_VARIANT_2","dimension42":"MIGHTY_MONTH_2022_HOLDOUT.MIGHTY_MONTH_ON","dimension184":"NFSHDP_OWNER_OPTIONS_GOOGLE_AD.ON","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension41":"RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT_MULTIVARIATE.CONTROL","dimension36":"RE_RENTER_PROFILE_V3_REFRESH.AA_VARIANT","dimension62":"RE_SECOND_BOOST.SLOT_4","dimension37":"SET_COMPARE.ON","dimension187":"SPT_RENDER_FOR_SALE_PAGE.ON","dimension166":"SXP_HDP_Load_Order.OPTIMIZED","dimension40":"SXP_NONMLS_OFF.CONTROL","dimension38":"VL_EXPANDED_CONTENT.BUTTON","dimension60":"VL_FACTS_AND_FEATURES_REDESIGN.TEST","dimension61":"VL_FLOORPLAN_NAMES.ON","dimension45":"VL_HDP_MODULE.MORE_UNITS","dimension59":"VL_HEADER_OPTIMIZATION.ON","dimension181":"YOLT_NO_OB_TOURS_ATL.CONTROL","dimension182":"YOLT_NO_OB_TOURS_PHX.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.CsIikOBC0Vbw","dimension65":"ZO_FSHDP_RTBP.ON","dimension167":"ZXR_EXPERIMENT_AA_TEST.CONDITION_A"}); ga('set', {"dimension46":"AB_DASHBOARD_AA_TEST.CONTROL","dimension185":"AIPERS_COLLECTIONS_UPDATES_TAB.MODEL_C_1","dimension50":"ARCS_ABAD_PHX.ON","dimension44":"ARCS_CLICK_TO_CALL_TRACKING.CONTROL","dimension56":"ARCS_PA_ZHL_LEAD.T1_OPAQUE_LIGHTBOX_ONLY_ABAD_ABC_ONLY","dimension39":"ARCS_TOUR_UPGRADE_V1.ARCS_TOUR_UPGRADE_PLAIN","dimension49":"AR_BUYER_INITIATED_RELATIONSHIP_UI.CONTROL","dimension64":"DXP_RTB_LINKING.CONTROL","dimension57":"HDP_HFF_ACCORDION.CONTROL","dimension58":"HDP_SELLING_SOON_MSG.MOBILE_VARIANT_2","dimension42":"MIGHTY_MONTH_2022_HOLDOUT.MIGHTY_MONTH_ON","dimension184":"NFSHDP_OWNER_OPTIONS_GOOGLE_AD.ON","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension41":"RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT_MULTIVARIATE.CONTROL","dimension36":"RE_RENTER_PROFILE_V3_REFRESH.AA_VARIANT","dimension62":"RE_SECOND_BOOST.SLOT_4","dimension37":"SET_COMPARE.ON","dimension187":"SPT_RENDER_FOR_SALE_PAGE.ON","dimension166":"SXP_HDP_Load_Order.OPTIMIZED","dimension40":"SXP_NONMLS_OFF.CONTROL","dimension38":"VL_EXPANDED_CONTENT.BUTTON","dimension60":"VL_FACTS_AND_FEATURES_REDESIGN.TEST","dimension61":"VL_FLOORPLAN_NAMES.ON","dimension45":"VL_HDP_MODULE.MORE_UNITS","dimension59":"VL_HEADER_OPTIMIZATION.ON","dimension181":"YOLT_NO_OB_TOURS_ATL.CONTROL","dimension182":"YOLT_NO_OB_TOURS_PHX.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.CsIikOBC0Vbw","dimension65":"ZO_FSHDP_RTBP.ON","dimension167":"ZXR_EXPERIMENT_AA_TEST.CONDITION_A"});
#     </script><script>
#         !function () {
#             // Getting OptanonConsent cookie from document.cookie
#             var n = !1,
#                 op = document.cookie && document.cookie.split("; ").filter(function(n){ return n.indexOf("OptanonConsent=") === 0; });
#             try {
#                 var o = op && op.length > 0 && op[0];
#                 if (void 0 !== o && null != o) {
#                     // Parse and read OptanonConsent cookie, look for groups.
#                     var i = decodeURIComponent(o).split("&").filter(function(n) { return n.indexOf("groups=") !== -1; });
#                     if(i.length > 0) {
#                         // Groups will look like 1:0,3:0,4:0. We want to check if the 3:0 exists, which is the code for functional blocking
#                         var m = i[0].substring(i[0].indexOf("=")).split(",");
#                         for (var k = 0; k < m.length; k++) {
#                             m[k].split(":").length > 1 && "3" === m[k].split(":")[0] && "0" === m[k].split(":")[1] && (n = !0)
#                         }
#                     }
#                 }
#             }
#             catch(e) {};
#             window['ga-disable-' + 'UA-21174015-56'] = n;
#             window['disable-analytics'] = n;
#         }();
#
#         (function(w,d,ns,cdn,opt,ml,fa,my,fst){
#         w['ZillowAnalyticsObject']=ns;w[ns]=w[ns]||[];
#         if(w[ns].initialize||w[ns].invoked)return;
#         w[ns].invoked=1;w[ns]._loadOptions=opt;
#         ml=['identify','track','page','off','on','use','unuse','setdim','setprop','event','send','dwell','dwellEnd'];
#         fa=function(m){return function(){w[ns].push([].concat(m,[].slice.call(arguments)));return w[ns]}};
#         ml.forEach(function(mn){w[ns][mn]=fa(mn)});
#         var x=!(window && window['disable-analytics']);
#         if(x){my=d.createElement('script');fst=d.getElementsByTagName('script')[0];
#         my.defer=!0;my.src=cdn;if(fst)fst.parentNode.insertBefore(my,fst);}
#         return w[ns];
#         })(window,document,'zanalytics', 'https://e.zg-api.com/a/z/js/v1/analytics.js?v=bcf290c', {'zillow': {
#             apiKey: 'z_prod',
#             apiHost: 'e.zg-api.com:443',
#             secure: true,
#             anonymousId: '666c37a2-4033-4183-ad2a-41da562008d8',
#         }});</script><script>
#         var customDimension1 = '666c37a240334183ad2a41da562008d8';
#         ua('set', 'dimension1', customDimension1);
#         ga('set', 'dimension1', customDimension1);</script><script>
#         var w = window.innerWidth
#             || (document && document.documentElement && document.documentElement.clientWidth)
#             || (document && document.body && document.body.clientWidth);
#
#         var h = window.innerHeight
#             || (document && document.documentElement && document.documentElement.clientHeight)
#             || (document && document.body && document.body.clientHeight);
#
#         ua('set', 'dimension20', w + "x" + h);
#         ua('set','dimension68', window.location.href);
#         ua('set', 'dimension69', document.referrer);
#         ua('set', 'dimension192', '1644699012597');
#         ga('set', 'dimension20', w + "x" + h);
#         ga('set','dimension68', window.location.href);
#         ga('set', 'dimension69', document.referrer);
#         ga('set', 'dimension192', '1644699012597');
#
#         document.addEventListener('DOMContentLoaded', function ProfileDOMContentLoadedEvent (e) {
#             // wait two seconds to make sure this performance metric has been recorded
#             setTimeout(function () {
#                 if (performance && performance.timing) {
#                     var domContentLoadedTime = ((performance.timing.domContentLoadedEventStart - performance.timing.navigationStart)/1000).toFixed(2);
#                     ua('set', 'dimension72', domContentLoadedTime);
#                     ga('set', 'dimension72', domContentLoadedTime);
#                 }
#             }, 2000);
#             document.removeEventListener('DOMContentLoaded', ProfileDOMContentLoadedEvent);
#         });
#
#         window.addEventListener('load', function ProfileLoadEvent (e) {
#             // wait two seconds to make sure this performance metric has been recorded
#             setTimeout(function () {
#                 if (performance && performance.timing) {
#                     var loadEventTime = ((performance.timing.loadEventEnd - performance.timing.navigationStart)/1000).toFixed(2);
#                     ua('set', 'dimension73', loadEventTime);
#                     ga('set', 'dimension73', loadEventTime);
#                 }
#             }, 2000);
#             window.removeEventListener('load', ProfileLoadEvent);
#         });
#     </script><script type="text/javascript">ua('set', {"dimension46":"AB_DASHBOARD_AA_TEST.CONTROL","dimension185":"AIPERS_COLLECTIONS_UPDATES_TAB.MODEL_C_1","dimension50":"ARCS_ABAD_PHX.ON","dimension44":"ARCS_CLICK_TO_CALL_TRACKING.CONTROL","dimension56":"ARCS_PA_ZHL_LEAD.T1_OPAQUE_LIGHTBOX_ONLY_ABAD_ABC_ONLY","dimension39":"ARCS_TOUR_UPGRADE_V1.ARCS_TOUR_UPGRADE_PLAIN","dimension49":"AR_BUYER_INITIATED_RELATIONSHIP_UI.CONTROL","dimension64":"DXP_RTB_LINKING.CONTROL","dimension57":"HDP_HFF_ACCORDION.CONTROL","dimension58":"HDP_SELLING_SOON_MSG.MOBILE_VARIANT_2","dimension42":"MIGHTY_MONTH_2022_HOLDOUT.MIGHTY_MONTH_ON","dimension184":"NFSHDP_OWNER_OPTIONS_GOOGLE_AD.ON","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension41":"RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT_MULTIVARIATE.CONTROL","dimension36":"RE_RENTER_PROFILE_V3_REFRESH.AA_VARIANT","dimension62":"RE_SECOND_BOOST.SLOT_4","dimension37":"SET_COMPARE.ON","dimension187":"SPT_RENDER_FOR_SALE_PAGE.ON","dimension166":"SXP_HDP_Load_Order.OPTIMIZED","dimension40":"SXP_NONMLS_OFF.CONTROL","dimension38":"VL_EXPANDED_CONTENT.BUTTON","dimension60":"VL_FACTS_AND_FEATURES_REDESIGN.TEST","dimension61":"VL_FLOORPLAN_NAMES.ON","dimension45":"VL_HDP_MODULE.MORE_UNITS","dimension59":"VL_HEADER_OPTIMIZATION.ON","dimension181":"YOLT_NO_OB_TOURS_ATL.CONTROL","dimension182":"YOLT_NO_OB_TOURS_PHX.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.CsIikOBC0Vbw","dimension65":"ZO_FSHDP_RTBP.ON","dimension167":"ZXR_EXPERIMENT_AA_TEST.CONDITION_A"}); ga('set', {"dimension46":"AB_DASHBOARD_AA_TEST.CONTROL","dimension185":"AIPERS_COLLECTIONS_UPDATES_TAB.MODEL_C_1","dimension50":"ARCS_ABAD_PHX.ON","dimension44":"ARCS_CLICK_TO_CALL_TRACKING.CONTROL","dimension56":"ARCS_PA_ZHL_LEAD.T1_OPAQUE_LIGHTBOX_ONLY_ABAD_ABC_ONLY","dimension39":"ARCS_TOUR_UPGRADE_V1.ARCS_TOUR_UPGRADE_PLAIN","dimension49":"AR_BUYER_INITIATED_RELATIONSHIP_UI.CONTROL","dimension64":"DXP_RTB_LINKING.CONTROL","dimension57":"HDP_HFF_ACCORDION.CONTROL","dimension58":"HDP_SELLING_SOON_MSG.MOBILE_VARIANT_2","dimension42":"MIGHTY_MONTH_2022_HOLDOUT.MIGHTY_MONTH_ON","dimension184":"NFSHDP_OWNER_OPTIONS_GOOGLE_AD.ON","dimension180":"ONSITE_MESSAGE_VALVE.OMP_ON","dimension41":"RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT_MULTIVARIATE.CONTROL","dimension36":"RE_RENTER_PROFILE_V3_REFRESH.AA_VARIANT","dimension62":"RE_SECOND_BOOST.SLOT_4","dimension37":"SET_COMPARE.ON","dimension187":"SPT_RENDER_FOR_SALE_PAGE.ON","dimension166":"SXP_HDP_Load_Order.OPTIMIZED","dimension40":"SXP_NONMLS_OFF.CONTROL","dimension38":"VL_EXPANDED_CONTENT.BUTTON","dimension60":"VL_FACTS_AND_FEATURES_REDESIGN.TEST","dimension61":"VL_FLOORPLAN_NAMES.ON","dimension45":"VL_HDP_MODULE.MORE_UNITS","dimension59":"VL_HEADER_OPTIMIZATION.ON","dimension181":"YOLT_NO_OB_TOURS_ATL.CONTROL","dimension182":"YOLT_NO_OB_TOURS_PHX.ON","dimension188":"ZEXP_DECISION_TOKEN_HOLD.CsIikOBC0Vbw","dimension65":"ZO_FSHDP_RTBP.ON","dimension167":"ZXR_EXPERIMENT_AA_TEST.CONDITION_A"});</script><script>window.UI_INIT_AT = Date.now()</script><script>(function(n,r,e){var a="v2",o="fontsVersion",t="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700&display=swap",s="//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-",i="",c="",l={};var f=function(){var e="__zstorage__";try{localStorage.setItem(e,e);localStorage.removeItem(e);return true}catch(e){return false}}();var u=function(){try{return r.createElement("link").relList.supports("prefetch")}catch(e){return false}}();function d(e){var t=n.requestIdleCallback;t&&t(e)||setTimeout(e,1)}function p(e){var t=r.createElement("style");t.type="text/css";t.appendChild(r.createTextNode(e));r.head.appendChild(t)}function S(e,t){var n=r.createElement("link");n.rel=t;n.href=e;r.head.appendChild(n)}l.insertOpenSansStyle=function(){S(t,"stylesheet")};l.setIvarStyle=function(e){i=e};l.insertIvarStyle=function(){i&&p(i)};l.setIvarSubsetStyle=function(e){c=e};l.insertIvarSubsetStyle=function(){c&&p(c)};l.prefetchIvarResources=function ...
#     ZillowFontLoader.setIvarStyle('@font-face{font-family:Ivar Headline;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff2) format("woff2"),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-extended.woff) format("woff");font-weight:600;font-style:normal;font-display:swap;unicode-range:u+0000-001f,u+0080-200f,u+2020-faff,u+fb10-ffff}@font-face{font-family:Ivar Headline;src:url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff2) format("woff2"),url(//www.zillowstatic.com/static-zsg/LATEST/static-zsg/zsg/z-fonts/ivar/IvarHeadline-SemiBold-core.woff) format("woff");font-weight:600;font-style:normal;font-display:swap;unicode-range:u+0020-007f,u+201?,u+fb0?}');</script><script>ZillowFontLoader.setIvarSubsetStyle('@font-face{font-family:Ivar Headline Subset;src:url("data:application/x-font-woff2;charset=utf-8;base64,...") format("woff2");font-weight:600;font-style:normal;font-display:swap;unicode-range:u+0020,u+0041-005a,u+0061-007a}');</script><script>ZillowFontLoader.init();</script><link href="//fonts.googleapis.com" rel="dns-prefetch"/><meta charset="utf-8"/><meta content="telephone=no" name="format-detection"/><meta content="on" http-equiv="x-dns-prefetch-control"/><meta content="always" name="referrer"/><meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><meta content="#3366b8" name="msapplication-TileColor"/><meta content="https://www.zillowstatic.com//static/images/logos/zillow-logo-win8-tile.png" name="msapplication-TileImage"/><meta content="none" name="msapplication-config"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/><link href="/apple-touch-icon.png" rel="apple-touch-icon"/><meta content="172285552816089" property="fb:app_id"/><meta content="691f1bfccade71b5-c065751219a379dd-g64cedb67f5ea020a-a" name="google-translate-customization"/><meta content="238648973530.apps.googleusercontent.com" name="google-signin-clientid"/><meta content="openid profile email" name="google-signin-scope"/><meta content="single_host_origin" name="google-signin-cookiepolicy"/><meta content="Zillow" property="og:site_name"/><script>(function() {
#             if (typeof ga===undefined||!Array.isArray(ga.q)){return}
#             var gaSetCalls=[].concat(ga.q).filter(function(args){return args && args[0]==='set'});
#             var dims = {};
#             gaSetCalls.forEach(function(cmdCall) {
#                 var arg1=cmdCall[1], arg2=cmdCall[2];
#                 if (typeof arg1==='string') {
#                     dims[arg1] = arg2;
#                 } else if (typeof arg1==='object' && arg1!==null) {
#                     Object.getOwnPropertyNames(arg1).forEach(function(k) {dims[k] = arg1[k]});
#                 }
#             });
#             if (typeof zanalytics!=='undefined' && typeof zanalytics.setdim==='function') {zanalytics.setdim(dims)}
#         })();</script><script>
#             if (window.ClientProfiler) {
#                 window.ClientProfiler.appConfig = {
#                     staticBeaconData: {
#                         pageName: 'Search:RealEstateSearch:List',
#                         hostId: 'orb-del-pre-028',
#                         requestId: 'e5EU6-kBRPOImBKr2PAyaA'
#                     }
#                 }
#             }
#         </script><link href="//fonts.googleapis.com" rel="preconnect"/><link href="//maps.googleapis.com" rel="preconnect"/><link href="//c.go-mpulse.net" rel="preconnect"/><link href="//s.zillowstatic.com" rel="preconnect"/><link href="//fonts.gstatic.com" rel="preconnect"/><link href="//www.google-analytics.com" rel="preconnect"/><link href="//sb.scorecardresearch.com" rel="preconnect"/><link href="//e.zg-api.com" rel="preconnect"/><link crossorigin="true" href="//pf.zillow.com" rel="preconnect"/><link crossorigin="true" href="https://mortgageapi.zillow.com" rel="preconnect"/><script type="application/javascript">
#         !function(e){var t={};function __webpack_require__(n){if(t[n])return t[n].exports;var r=t[n]={i:n,l:!1,exports:{}};return e[n].call(r.exports,r,r.exports,__webpack_require__),r.l=!0,r.exports}__webpack_require__.m=e,__webpack_require__.c=t,__webpack_require__.d=function(e,t,n){__webpack_require__.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:n})},__webpack_require__.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},__webpack_require__.t=function(e,t){if(1&t&&(e=__webpack_require__(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var n=Object.create(null);if(__webpack_require__.r(n),Object.defineProperty(n,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var r in e)__webpack_require__.d(n,r,(function(t){return e[t]}).bind(null,r));return n},__webpack_require__.n=function(e){var t=e&&e.__esModule?function getDefault(){return e.default}:function getModuleExports(){return e};return __webpack_require__.d(t,"a",t),t},__webpack_require__.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},__webpack_require__.p="",__webpack_require__(__webpack_require__.s=0)}({"/uRe":function(e,t,n){"use strict";n.r(t);var r=n("5cLd"),i=n.n(r);function _defineProperty(e,t,n){return t in e?Object.defineProperty(e,t,{value:n,enumerable:!0,configurable:!0,writable:!0}):e[t]=n,e}var u=function LifeCycleEventQueue(){var e=this;_defineProperty(this,"checkRefire",(function(){!e.pendingRefireAnimationFrame&&(e.pendingScriptCount>0||e.hasFired)&&(e.pendingRefireAnimationFrame=!0,window.setTimeout((function(){return e.loadAssets()}),0))})),_defineProperty(this,"addCss",(function(t){e.cssQueue.push(t),e.checkRefire()})),_defineProperty(this,"addScript",(function(t){e.scriptQueue.push(t),e.checkRefire()})),_defineProperty(this,"addCallback",(function(t){e.callbackQueue.push(t),e.checkRefire()})),_defineProperty(this,"loadAssets",(function(){e.testHookOverride?e.testHookOverride():(e.loadCss(),e.loadScripts(),e.pendingRefireAnimationFrame=!1)})),_defineProperty(this,"loadCss",(function(){var t=document.getElementsByTagName("head")[0];if(t&&0!==e.cssQueue.length){var n=e.cssQueue.reduce((function(e,t){return e+'<link href="'+t+'" type="text/css" rel="stylesheet" />'}),"");t.insertAdjacentHTML("beforeend",n),e.cssQueue=[]}})),_defineProperty(this,"loadScripts",(function(){document.getElementsByTagName("head")[0]&&e.scriptQueue.length>0&&(e.pendingScriptCount+=e.scriptQueue.length,e.scriptQueue.forEach((function(t){Array.isArray(t)?e.loadScriptSequence(t):e.loadScript(t)})),e.scriptQueue=[]),e.pendingScriptCount++,e.onScriptLoad()})),_defineProperty(this,"loadScript",(function(t){var n=document.getElementsByTagName("head")[0],r=document.createElement("script");r.setAttribute("src",t),r.addEventListener("load",e.onScriptLoad),n.appendChild(r)})),_defineProperty(this,"loadScriptSequence",(function(t){if(1!==t.length){var n=[].concat(t),r=document.getElementsByTagName("head")[0],i=document.createElement("script"),u=n.shift();i.setAttribute("src",u),i.addEventListener("load",(function(){return e.loadScriptSequence(n)})),r.appendChild(i)}else e.loadScript(t[0])})),_defineProperty(this,"onScriptLoad",(function(){e.pendingScriptCount>0&&e.pendingScriptCount--,0===e.pendingScriptCount&&window.setTimeout((function(){return e.fireCallbacks()}),0)})),_defineProperty(this,"fireCallbacks",(function(){e.callbackQueue.forEach((function(e){return e()})),e.callbackQueue=[],e.hasFired=!0})),_defineProperty(this,"addLoadAssetsTestOverride",(function(t){e.testHookOverride=t})),_defineProperty(this,"clearLoadAssetsTestOverride",(function(){e.testHookOverride=null})),this.scriptQueue=[],this.cssQueue=[],this.callbackQueue=[],this.pendingScriptCount=0,this.loadingAssets=!1,this.hasFired=!1,this.testHookOverride=null,this.pendingRefireAnimationFrame=!1};function LifeCycleQueueEventManager_defineProperty(e,t ...
#         window.lifecycleQueue = new LifeCycleQueueEventManager();
#         window.addEventListener("load", function () {
#             window.lifecycleQueue.loadloadEventAssets();
#         });
#     </script><link as="image" href="" id="mapPrefetch" rel="preload"/><script type="application/javascript">
#             window.mapPlaceholders = {"3":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=3&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=JPdGyiuT8KuROj-BpsmwRQvDo4M=","4":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=4&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=YIljOsphEpM9yII7ifowa_mSW9E=","5":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=5&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=pFzO0I6HUFWLtk94YA1TT6SUfVc=","6":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=6&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=XMYEeDIyH2_4Cb8ayUAp_LYJCTY=","7":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=7&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=G645mFR8R04NMV_GB9eaZ0FKJTo=","8":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=8&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=5uLoq6Z3UR1im8Ooap3E7F41G_4=","9":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=9&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=Kfpn5oCBNwZWTQ_hC_SBpjup4Lo=","10":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=10&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=SEh4vCKihq5jPCYcNLI5dNAL1yQ=","11":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=11&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=08-W-ob_7Isya5QHRR-edYWA9tc=","12":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=12&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=5ifSZtmLTwA0_kWfkVxpt0YLeWs=","13":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=13&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=yGejEFK0IlyQXfP3qSrAFSjT-Ow=","14":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=14&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=gTMjjxwszhJUeM0f7BtnJY410Ak=","15":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=15&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=h0rlScB0JbTR3KVQ7omAzsuKQaI=","16":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=16&size=905x720&maptype=roadmap&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=rMLWro3y7CBszykpFTBZJVFzOfc=","17":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80.297717&zoom=17&size=905x720&maptype=satellite&key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&style=feature%3Aall%7Celement%3Alabels%7Cvisibility%3Aoff&signature=FQcpdqLtQ8LFOlE5BqGPIXjgz0g=","18":"https://maps.googleapis.com/maps/api/staticmap?center=25.726229,-80. ...
#
#             // Polyfill for IE11
#             Math.tanh = Math.tanh || function(x){
#                 var a = Math.exp(+x), b = Math.exp(-x);
#                 return a == Infinity ? 1 : (b == Infinity ? -1 : (a - b) / (a + b));
#             }
#
#             function degreesToRadians(deg) {
#               return deg * (Math.PI / 180);
#             }
#
#             function radiansToDegrees(rad) {
#               return rad / (Math.PI / 180);
#             }
#
#             function getBoundsAndZoomLevel(northLat, southLat, westLng, eastLng, spaceHeight, spaceWidth) {
#                 var WORLD_DIM = { height: 256, width: 256 };
#                 var ZOOM_MAX = 19;
#
#                 function latRad(lat) {
#                     var sin = Math.sin(degreesToRadians(lat));
#                     var radX2 = Math.log((1 + sin) / (1 - sin)) / 2;
#                     return Math.max(Math.min(radX2, Math.PI), -Math.PI) / 2;
#                 }
#
#                 function fracToZoom(mapPx, worldPx, fraction) {
#                     var v = Math.log(mapPx / worldPx / fraction) / Math.LN2;
#                     // Adjust for floating error on exact fit
#                     return Math.floor(v + 0.00001);
#                 }
#
#                 function zoomToFrac(mapPx, worldPx, zoom) {
#                     return (mapPx / worldPx) / Math.exp(zoom * Math.LN2);
#                 }
#
#                 // ====================================================================
#                 // Calculate the zoom level to fit these bounds into the given viewport
#                 // ====================================================================
#
#                 // Sphere math to turn lat and long into degrees out of 360
#                 var latRadNorth = latRad(northLat);
#                 var latRadSouth = latRad(southLat);
#                 var latRadDiff = latRadNorth - latRadSouth;
#                 var latFraction = latRadDiff / Math.PI;
#
#                 var lngDiff = eastLng - westLng;
#                 var lngFraction = ((!(lngDiff >= 0)) ? (lngDiff + 360) : lngDiff) / 360;
#
#                 var latZoom = fracToZoom(spaceHeight, WORLD_DIM.height, latFraction);
#                 var lngZoom = fracToZoom(spaceWidth, WORLD_DIM.width, lngFraction);
#
#                 var finalZoom = Math.min(latZoom, lngZoom, ZOOM_MAX);
#
#                 // ========================================================
#                 // Calculate the viewport-exact bounds for this zoom level
#                 // ========================================================
#
#                 var fittedLngFraction = zoomToFrac(spaceWidth, WORLD_DIM.width, finalZoom);
#                 var lngDegreeCenter = (eastLng + westLng) / 2;
#                 var fittedLngDiff = lngDiff * (fittedLngFraction / lngFraction)
#                 var fittedWestLng = lngDegreeCenter - (fittedLngDiff / 2);
#                 var fittedEastLng = lngDegreeCenter + (fittedLngDiff / 2);
#
#                 var fittedLatRadFraction = zoomToFrac(spaceHeight, WORLD_DIM.height, finalZoom);
#                 var latRadCenter = (latRadNorth + latRadSouth) / 2;
#                 var fittedLatRadDiff = latRadDiff * (fittedLatRadFraction / latFraction);
#                 var fittedNorthLat = radiansToDegrees(Math.asin(Math.tanh(2 * (latRadCenter + (fittedLatRadDiff/2)))));
#                 var fittedSouthLat = radiansToDegrees(Math.asin(Math.tanh(2 * (latRadCenter - (fittedLatRadDiff/2)))));
#
#                 return {
#                     zoom: finalZoom,
#                     bounds: {
#                         northLat: fittedNorthLat,
#                         southLat: fittedSouthLat,
#                         eastLng: fittedEastLng,
#                         westLng: fittedWestLng,
#                     }
#                 }
#             }
#
#             /*
#                 This must be kept synchronized with these vars in https://gitlab.zgtools.net/zillow/searchxp/static-search-page/-/blob/master/src/search-app/less/constants.less
#                     @wideSingleColumnMinWidth
#                     @wideDoubleColumnMinWidth
#                     @searchListSingleColumnWidth_DoubleColTest
#                     @searchListDoubleColumnWidth_DoubleColTest
#             */
#             function getListCardColumnWidth() {
#                 if (window.innerWidth >= 1280) {
#                     return 750;
#                 } else if (window.innerWidth >= 1007) {
#                     return 375;
#                 } else {
#                     return 0;
#                 }
#             }
#
#             var northLat = 25.855773;
#             var southLat = 25.596685;
#             var westLng = -80.456276;
#             var eastLng = -80.139157;
#
#             var Z_HEADER_HEIGHT = 80;
#             var SRP_HEADER_HEIGHT = 55;
#
#             // Only prefetch when the window is wide enough to display a map and list view
#             if (window.innerWidth >= 1007){
#                 var boundsAndZoom = getBoundsAndZoomLevel(northLat, southLat, westLng, eastLng, window.innerHeight - SRP_HEADER_HEIGHT - Z_HEADER_HEIGHT, window.innerWidth - getListCardColumnWidth());
#                 window.boundsAndZoom = boundsAndZoom;
#                 // Use a placeholder image one zoom level out, since we are stretching the image out 2x, which has the effect of zooming in.
#                 window.selectedPrefetch = window.mapPlaceholders[boundsAndZoom.zoom-1];
#
#                 // Kick off a prefetch since the image won't be actually consumed till SSP initial render
#                 document.querySelector("#mapPrefetch").href = window.selectedPrefetch;
#             }
#         </script><script>window.cpErrors=0;window._onSentryLoad=function(){Sentry.onLoad(function(){Sentry.init({sampleRate:0.02,environment:"production",beforeSend:function(a){window.cpErrors++;return a}})})};lifecycleQueue.addCallbackToEvent(function(){Sentry.forceLoad()},"priorityUIReady");</script><script crossorigin="anonymous" defer="true" onload="window._onSentryLoad()" src="https://js.sentry-cdn.com/11f110c8142f4b9f8bf48c0775de8d17.min.js"></script><script type="text/javascript">window.addEventListener("load",function(){var a=document.getElementsByTagName("head");if(a&&a.length>0){a[0].insertAdjacentHTML("beforeend","")}},false);</script><style>
#             select {
#     background-image:url(...);
#     background-repeat:no-repeat;
#     border-radius:0;
#     line-height:20px;
#     padding:0 23px 0 6px;
#     -moz-appearance:none; /* stylelint-disable-line */
# }
#
# input:focus,
# select:focus{border-color:#006AFF;box-shadow:inset 0 0 0 #F9F9FB,0 0 5px #62aef7;outline:0;transition:box-shadow .3s;}
#
# input[disabled],
# select[disabled]{background-color:#F1F1F4;border-color:#A7A6AB;box-shadow:none;color:#A7A6AB}
#
# html input[disabled] {cursor:default}
# input[disabled]::-moz-placeholder{color:#A7A6AB}
# input[disabled]::-webkit-input-placeholder{color:#A7A6AB}
# input[disabled]:-moz-placeholder{color:#A7A6AB}
# input[disabled]:-ms-input-placeholder{color:#A7A6AB}
# input[type=checkbox]{border:0;box-sizing:border-box;height:auto;left:-9999px;padding:0;position:absolute;width:auto;}
# input[type=checkbox]:active,
# input[type=checkbox]:focus,
# input[type=checkbox]:hover{border:0}
# .zsg-fineprint{font-family:"Open Sans",Gotham,gotham,Tahoma,Geneva,sans-serif;font-size:12px;line-height:1.5;font-weight:400;color:#54545A}
# h1,h2,h3,h4,h5,h6,p{margin-bottom:15px}
# @media screen and (max-width:480px) {h1,h2,h3,h4,h5,h6,p{margin-bottom:10px}}
# h1,h2,h3,h4,h5,h6{display:block}
# .zsg-subfooter-content{max-width:1280px;margin-left:auto;margin-right:auto;padding-left:20px;padding-right:20px}
# .zsg-layout_full .zsg-subfooter-content{max-width:none;margin-left:0;margin-right:0}
# @media screen and (max-width:480px) {.zsg-subfooter-content{padding-left:10px;padding-right:10px}}
# input[type=checkbox]+label,input[type=radio]+label{position:relative;-webkit-user-select:none;-moz-user-select:none;-o-user-select:none;-ms-user-select:none;user-select:none;display:inline-block}
# input[type=checkbox][disabled]+label,input[type=radio][disabled]+label{cursor:default}
# .zsg-footer-linklist{text-transform:uppercase}
# .zsg-list_inline>li{display:inline-block;vertical-align:top;margin-left:10px}
# .zsg-list_inline>li:first-child{margin-left:0}
# .zsg-table{display:table;width:100%}
# .zsg-table tr{display:table-row}
# .zsg-table td,.zsg-table th{border-bottom:1px solid #F1F1F4;display:table-cell;padding:5px 10px;text-align:left}
# .zsg-table .zsg-table-col_num{text-align:right}
# .zsg-modal-mask{display:none;z-index:1002;position:fixed;left:0;top:0;height:100%;width:100%;background-color:#fff;opacity:.9;filter:alpha(opacity=90)}
# .zsg-right-aligned{text-align:right}
# .zsg-footer-linklist-container{position:relative}
# .zsg-footer{background-color:#0A0A14;color:#54545A;text-align:center}
# .zsg-footer .zsg-separator_narrow{padding:0}
# .zsg-footer-copyright,.zsg-footer-nav li{padding-top:10px;color:#A7A6AB}
# .zsg-footer-nav li{margin:0 10px}
# .zsg-footer-nav{margin-bottom:0}
# .zsg-footer-copyright li{margin:0 20px;vertical-align:middle}
# .zsg-footer-copyright li:last-child{margin:0}
# .zsg-footer-copyright .zsg-footer-follow{display:-webkit-box;display:-ms-flexbox;display:-ms-flex;display:flex;-moz-align-items:center;-ms-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center}
# .zsg-footer-copyright .zsg-footer-follow>span{margin:0 20px}
# .zsg-footer-copyright .zsg-footer-follow a{margin-right:15px;font-size:30px;color:#54545A}
# .zsg-footer-row{text-align:center;margin:auto;padding-bottom:10px}
# @media screen and (max-width:768px) {.zsg-footer-linklist-container{height:40px;overflow:hidden;padding-right:20px}}
# .zsg-footer-linklist{font-size:13px;line-height:1.5;font-weight:600}
# @media screen and (max-width:480px) {.zsg-footer-linklist{font-size:13px}}
# .zsg-footer-linklist a{color:#A7A6AB;font-weight:700}
# .zsg-footer-linklist a:visited{color:#A7A6AB}
# .zsg-footer-linklist a:hover{color:#006AFF}
# .zsg-footer-linklist a:active{color:#0D4599}
# .zsg-footer-linklist li:first-child{margin-left:15px}
# .zsg-subfooter{background-color:#F1F1F4;padding-top:30px;text-align:left;font-size:12px}
# .zsg-subfooter-content{padding-bottom:0}
# .zsg-subfooter-content [class*=" zsg-lg-"],.zsg-subfooter-content [class^=zsg-lg-]{margin-bottom:30px}
# .zsg-subfooter-linklist li{margin-bottom:10px}
# .zsg-subfooter-linklist li:last-child{margin-bottom:0}
# .zsg-subfooter-linklist a,.zsg-subfooter-linklist a:visited{color:#2A2A33}
# .zsg-subfooter-linklist a:hover{color:#006AFF}
# .zsg-subfooter-linklist a:active{color:#0D4599}
# .zsg-separator{border-color:#A7A6AB;border-style:solid;border-width:0 0 1px;margin-bottom:10px;padding-bottom:10px}
# .zsg-separator_narrow{margin-bottom:5px;padding-bottom:5px}
#         </style><style>
#             .map-toggle-container,.map-toggle-container .map-toggle-label{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none}
# .lightbox-transition-leave .yui3-lightbox-content.fade,.map-toggle-container .map-toggle-label .map-toggle-label-before{opacity:0}
# .mobile-search-page #Adsencegoogleads{margin-bottom:0}
# body.responsive-search-page .search-page-container .list-card-save{-webkit-transform:translate3d(0,0,0)}
# body.responsive-search-page.zsg-layout_full{padding-left:0}
# body.responsive-search-page #content{height:auto}
# body.responsive-search-page #z-app-root:empty{display:none}
# body.responsive-search-page #region-info-footer{padding-bottom:15px}
# body.zsg-lightbox_scroll.hold-scroll{position:static}
# @media screen and (min-width:1007px){body.responsive-search-page .znav-nav.zsg-layout-width{padding-left:0}
# }
# #search-page-connect-mobile-dialog .mobile-dialog{visibility:visible}
# #pfs-nav-wrapper>#page-header-container>.znav-mobile-open{z-index:1001}
# .base-filters form{margin:0 auto;padding-bottom:0}
# .base-filters fieldset{margin:0 0 15px}
# .base-filters legend{line-height:1.5;font-weight:600;text-transform:uppercase;margin-bottom:15px}
# .base-filters .text-input-range-inner{display:flex}
# .base-filters .text-input-range-inner>label{width:100%}
# .base-filters .text-input-range-inner .zsg-form-field{flex:1 1 50%}
# .base-filters .text-input-range-dash{align-items:center;color:#D1D1D5;display:inline-flex;padding:0 5px}
# .base-filters .filter_baths .zsg-form-button-group,.base-filters .filter_beds .zsg-form-button-group{display:flex}
# .base-filters .filter_baths .zsg-form-button-group>li,.base-filters .filter_beds .zsg-form-button-group>li{flex:1}
# .base-filters .filter_baths .zsg-form-button-group label,.base-filters .filter_beds .zsg-form-button-group label{display:block}
# .button_unstyled{background:0 0;border:0;padding:0}
# .search-page-action-bar{display:flex;flex-grow:1;flex-direction:row;align-items:center}
# .search-page-action-bar .action-bar-right-content{display:flex;align-items:center;margin-left:auto}
# @media screen and (max-width:1085px){.search-page-action-bar .action-bar-right-content{display:none}
# body.fav-view .search-page-action-bar .action-bar-right-content{display:flex}
# }
# .search-page-action-bar .saved-homes-link{display:flex;align-items:center;margin-right:10px;padding:0 10px;height:50px}
# .map-toggle-text{visibility:hidden}
# @media screen and (min-width:1280px){.map-toggle-text{visibility:visible}
# }
# .map-toggle-text-container{padding-right:10px}
# .map-toggle-container{position:relative;height:30px;width:50px;margin-right:25px;user-select:none}
# .map-toggle-container .map-toggle-checkbox{display:none;left:0;width:14px;height:14px;position:relative;cursor:pointer;margin:0;outline:0}
# .map-toggle-container .map-toggle-checkbox:checked{border-color:#006AFF;border-width:1px;background:url(data:image/svg+xml;utf8,%20%20%20%20%3Csvg%20width%3D%2210%22%20height%3D%228%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%3E%0A%20%20%20%20%20%20%20%20%3Cpath%20d%3D%22M9.79.22a.72.72%200%200%200-1.04%200L3.72%206.15l-2.47-2.6a.72.72%200%200%200-1.04%200c-.28.29-.28.8%200%201.09l3%203.15c.15.17.31.21.51.21s.36-.08.52-.21L9.8%201.31c.28-.29.28-.8%200-1.09z%22%20fill%3D%22%23FFF%22%20fill-rule%3D%22nonzero%22%2F%3E%0A%20%20%20%20%3C%2Fsvg%3E) 1px 2px no-repeat,#006AFF}
# .map-toggle-container .map-toggle-label{display:inline-block;user-select:none;background-color:#F1F1F4;cursor:pointer;position:relative;height:30px;width:50px;border-radius:15px}
# .map-toggle-container .map-toggle-label,.map-toggle-container .map-toggle-label .map-toggle-label-before,.map-toggle-container .map-toggle-label:before{transition:left .35s ease 0s}
# .map-toggle-container .map-toggle-label .map-toggle-label-before,.map-toggle-container .map-toggle-label:before{position:absolute;content:'';top:5px;left:5px;width:20px;height:20px;background-size:20px;color:#F1F1F4;background-color:#D1D1D5;background-image:url(data:image/svg+xml,%3Csvg%20width%3D%2220%22%20height%3D%2220%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%3E%3Cpath%20d%3D%22M9.8%209l3-3c.2-.2.2-.6%200-.8-.3-.3-.7-.3-.9%200l-3%203-2.8-3c-.3-.3-.7-.3-1%200-.1.2-.2.6%200%20.9l3%202.9-3%203c-.2.2-.2.6%200%20.8l.5.2c.2%200%20.3%200%20.5-.2l2.9-3%203%203%20.4.2c.1%200%20.3%200%20.4-.2.3-.2.3-.6%200-.9l-3-2.9z%22%20fill%3D%22%23FFF%22%2F%3E%3C%2Fsvg%3E);border-radius:50%}
# .map-toggle-container .map-toggle-label:after{display:none!important}
# .map-toggle-container .map-toggle-checkbox:focus+.map-toggle-label{box-shadow:0 0 0 1px #fff,0 0 3px 4px rgba(0,116,231,.4)}
# .map-toggle-container .map-toggle-checkbox:checked+.map-toggle-label{background-color:#006AFF}
# .map-toggle-container .map-toggle-checkbox:checked+.map-toggle-label .map-toggle-label-before{left:25px}
# .map-toggle-container .map-toggle-checkbox:checked+.map-toggle-label:before{content:'';background-color:#fff;background-image:url(data:image/svg+xml,%3Csvg%20width%3D%2220%22%20height%3D%2220%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%3E%3Cpath%20d%3D%22M13.8%207.2a.7.7%200%200%200-1%200l-4.4%205L6%2010a.7.7%200%200%200-1%200c-.2.2-.2.6%200%20.9L8%2013.5c.1.2.3.2.5.2.1%200%20.3%200%20.4-.2l5-5.4c.3-.2.3-.7%200-1z%22%20fill%3D%22%23006AFF%22%2F%3E%3C%2Fsvg%3E);color:#006AFF;left:25px}
# .action-bar-in-filters{height:50px;position:relative;margin-left:0;margin-right:0;border-bottom:1px solid #cfcfcf;z-index:10;flex-basis:100%}
# .action-bar-in-filters .action-bar-left-content,.action-bar-in-filters .action-bar-right-content{display:flex}
# .pinned .action-bar-in-filters{background:#FFF;position:fixed;z-index:10;top:0;left:0;right:0}
# .pinned.exposed-filters .action-bar-in-filters{position:relative}
# .action-bar-in-filters .action-bar-pagination{padding:14px 8px}
# @media screen and (min-width:325px){.action-bar-in-filters .action-bar-pagination{padding:14px 10px}
# }
# .action-bar-in-filters .zsg-toolbar-link{padding:0 8px}
# @media screen and (min-width:325px){.action-bar-in-filters .zsg-toolbar-link{padding:0 10px}
# }
# .action-bar-in-filters .zsg-toolbar-link:visited{color:#006AFF}
# .action-bar-in-filters .link-styled-button{background:0 0;color:#006AFF;line-height:inherit;margin:0}
# .action-bar-in-filters .link-styled-button:focus,.action-bar-in-filters .link-styled-button:hover{color:#A6E5FF}
# .action-bar-in-filters .link-styled-button:focus{box-shadow:none;color:#006AFF;outline:#006AFF solid 2px}
# .action-bar-in-filters .save-search-button{padding:0 10px;font-size:inherit;font-weight:inherit}
# .action-bar-in-filters .save-search-button:hover{background:0 0;color:#006AFF}
# .floating-action-bar{position:fixed;align-items:center;justify-content:center;transition:bottom .5s;line-height:50px;z-index:2;box-shadow:0 0 7px 1px rgba(0,0,0,.25);font-size:16px}
# .floating-action-bar :focus-within{box-shadow:none}
# .floating-action-bar.rounded,.floating-action-bar.rounded .action-bar-left-content,.floating-action-bar.rounded .action-bar-left-content a{border-radius:25px}
# .floating-action-bar.right-aligned{right:25px}
# .floating-action-bar .action-bar-left-content,.floating-action-bar .action-bar-right-content{display:flex;height:50px;width:105px;margin:0;box-shadow:0 0 1px 0 #000;border-radius:3px}
# ...
#                 try {
#                     var o = op && op.length > 0 && op[0];
#                     if (void 0 !== o && null != o) {
#                         var i = decodeURIComponent(o).split("&").filter(function(n) { return n.indexOf("groups=") !== -1; });
#                         if(i.length > 0) {
#                             var m = i[0].substring(i[0].indexOf("=")).split(",");
#                             for (var k = 0; k < m.length; k++) {
#                                 m[k].split(":").length > 1 && "3" === m[k].split(":")[0] && "0" === m[k].split(":")[1] && (n = !0)
#                             }
#                         }
#                     }
#                 } catch(e) {}
#                 window['ga-disable-' + 'UA-21174015-56'] = n;
#                 window['disable-analytics'] = n;
#             }();
#         </script><script>
# window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# </script><script>
# (function() {
#     function safeDim(isDbg) {
#         try { return  ({"cd6":null,"cd8":null,"cd22":"","cd1":"666c37a240334183ad2a41da562008d8","cd146":"12700","cd66":"Search","cd5":"Miami","ab_assignments":{"NFSHDP_CLAIMS_UPSELL":"VARIANT_D","SXP_HDP_Load_Order":"OPTIMIZED","ZXR_EXPERIMENT_AA_TEST":"CONDITION_A","VL_FACTS_AND_FEATURES_REDESIGN":"TEST","HDP_SELLING_SOON_MSG":"MOBILE_VARIANT_2","VL_HEADER_OPTIMIZATION":"ON","ARCS_TOUR_UPGRADE_V1":"ARCS_TOUR_UPGRADE_PLAIN","SXP_NONMLS_OFF":"CONTROL","ARCS_PA_ZHL_LEAD":"T1_OPAQUE_LIGHTBOX_ONLY_ABAD_ABC_ONLY","HDP_HFF_ACCORDION":"CONTROL","ARCS_ABAD_PHX":"ON","RE_RENTER_PROFILE_V3_REFRESH":"AA_VARIANT","SET_COMPARE":"ON","VL_EXPANDED_CONTENT":"BUTTON","YOLT_NO_OB_TOURS_PHX":"ON","ONSITE_MESSAGE_VALVE":"OMP_ON","YOLT_NO_OB_TOURS_ATL":"CONTROL","SPT_RENDER_FOR_SALE_PAGE":"ON","NFSHDP_OWNER_OPTIONS_GOOGLE_AD":"ON","AIPERS_COLLECTIONS_UPDATES_TAB":"MODEL_C_1","ZEXP_DECISION_TOKEN_HOLD":"l6vMnwVtjIUR","AR_BUYER_INITIATED_RELATIONSHIP_UI":"CONTROL","AB_DASHBOARD_AA_TEST":"CONTROL","ZO_FSHDP_RTBP":"ON","VL_HDP_MODULE":"MORE_UNITS","MIGHTY_MONTH_2022_HOLDOUT":"MIGHTY_MONTH_ON","VL_FLOORPLAN_NAMES":"ON","RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT_MULTIVARIATE":"CONTROL","RE_SECOND_BOOST":"SLOT_4","ARCS_CLICK_TO_CALL_TRACKING":"CONTROL","DXP_RTB_LINKING":"CONTROL"},"cd7":null,"cd25":"Desktop","cd197":"[43832660, 2077384999, 44183752, 70767374, 2066686741, 44167091, 43873395, 92439896, 92444011, 43862618, 44284115, 44225938, 44163090, 70772922, 43815737, 2075886382, 247651941, 43864622, 43871329, 43838866, 92436354, 43848535, 43829077, 247680925, 82416910, 44186226, 43813600, 2066585152, 248839403, 308907424, 70774248, 247650631, 43808498, 247653181, 44279554, 43843901, 43842032, 44189242, 162033257, 306397880]","seo_assignments":{"SEOTEST__RE_Add_BuildingOverview_SRP":"CONTROL","SEOTEST__SRP_PAGINATION":"ON"},"cd3":"FL","cd23":"ForSale","cd12":"Unrecognized","cd4":"Miami-Dade County","cd158":"USER","cd70":"Miami, FL","cd159":"","cd18":"Region-City","cd71":"globalrelevanceex","cd69":null,"cd68":"https://www.zillow.com/homes/for_sale/miami/10_p/"})}
#         catch (e) {if (isDbg) {console.error(e); }}
#         return {};
#     }
#     var _aid='666c37a2-4033-4183-ad2a-41da562008d8';
#     var _uid='';
#     var _host='e.zg-api.com:443';
#     var _key='z_prod';
#     var _pn='Search:RealEstateSearch:List';
#     var _rid='e5EU6-kBRPOImBKr2PAyaA';
#     var _adbg=false;
#     var secure=true;
#     var dim=safeDim(_adbg);
#     dim.requestId = _rid;
#     dim.name = _pn;
#
#     function zaload(w,d,ns,cdn,opt,ml,fa,my,fst){
#     w['ZillowAnalyticsObject']=ns;w[ns]=w[ns]||[];
#     if(w[ns].initialize||w[ns].invoked)return;
#     w[ns].invoked=1;w[ns]._loadOptions=opt;
#     ml=['identify','track','page','off','on','use','unuse','setdim','event','send','dwell','dwellEnd'];
#     fa=function(m){return function(){w[ns].push([].concat(m,[].slice.call(arguments)));return w[ns]}};
#     ml.forEach(function(mn){w[ns][mn]=fa(mn)});
#     if (!window['disable-analytics']) {
#         my=d.createElement('script');fst=d.getElementsByTagName('script')[0];
#
#             my.defer=!0;my.src=cdn;if(fst)fst.parentNode.insertBefore(my,fst);
#
#
#         return w[ns];
#     }
#     };
#
#     zaload(window,document,'zanalytics', 'https://e.zg-api.com/a/z/js/v1/analytics.js?v=bcf290c', {'zillow': {
#         apiKey: _key,
#         apiHost: _host,
#         secure: secure,
#         anonymousId: _aid,
#         dimensions: dim,
#     }});
#
#     if (_uid) { zanalytics.identify(_uid); }  else { zanalytics.identify(null); }
# })();
# /* Queue for Global UA Object */
# (function(w,n){w[n]=w[n]||function(){(w[n].q=w[n].q||[]).push(arguments)}})(window, 'ua');
# </script><noscript><img alt="" height="0" src="https://sb.scorecardresearch.com/b2?c1=2&amp;c2=6036206&amp;c3=&amp;c4=www.zillow.com/homes/for_sale/miami/10_p/&amp;c5=&amp;c6=&amp;c15=&amp;cv=1.3&amp;cj=1" style="display:none" width="0"/></noscript></div><script>
#             if (typeof window.ZMOB_nativeAPI === 'undefined') {
#                 var googleUAObj = {
#                     hitType: 'event',
#                     eventCategory: 'search',
#                     eventAction: 'Analytics Loaded',
#                 };
#                 window.ga('send', googleUAObj);
#             }
#         </script><script charset="utf-8" defer="true" src="https://s.zillowstatic.com/s3/static-search-page/69ea5ee8/search-app/static/js/ads-by-google.js" type="text/javascript"></script><script charset="utf-8" defer="true" src="https://s.zillowstatic.com/s3/static-search-page/69ea5ee8/runtime-0acf7f2c.js" type="text/javascript"></script><script charset="utf-8" defer="true" src="https://s.zillowstatic.com/s3/static-search-page/69ea5ee8/overall-commons-8d0a4115.js" type="text/javascript"></script><script charset="utf-8" defer="true" src="https://s.zillowstatic.com/s3/static-search-page/69ea5ee8/search-app/app-e4e90411.js" type="text/javascript"></script><script>
#             window._sharedMapInstanceCache = {
#                 instances:[],
#                 loadFinished: false,
#                 loadStarted: true,
#                 version: 1,
#             };
#             window._onGoogleMapLoad = function () {
#                 window._sharedMapInstanceCache.loadFinished=true;
#             }
#         </script><script defer="true" onload="window._onGoogleMapLoad()" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyA1uIgJLlFocMlwcu8b3wKPKkdT2mWV3AU&amp;libraries=common,util,map,overlay,onion,controls,stats,places,geometry&amp;v=3.45"></script><script>window.zBodyScripts=(function(){if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script request start")}if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script callback start")}window.addEventListener("DOMContentLoaded",function(){if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("dom ready");window.ClientProfiler.profile("dom ready complete")}});(function(){ga("require","ec")}());if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script callback end")}if(window.ClientProfiler&&window.ClientProfiler.profile){window.ClientProfiler.profile("body script request end")}});window.lifecycleQueue.addCallbackToEvent(window.zBodyScripts,"priorityUIReady");</script><script>ClientProfiler&&ClientProfiler.profile("html body ended");</script><script>
#                 lifecycleQueue.addScriptToEvent('https://s.zillowstatic.com/s3/pfs/oneTrust-e5576bd1bc923743d924.js', 'priorityUIReady');
#                 lifecycleQueue.addScriptToEvent('https://s.zillowstatic.com/s3/pfs/reg-2abed07073051dbf6f26.js', 'priorityUIReady');
#             </script><script>(function(){var m="add_",p="handler",j=p+"s",c="_"+p,a=m+p,f="invalid_field"+c,x="find",l="form",s="abort",i="value",b="events",e="cancel",r=e+"_"+j,g="on",y="submit",w=g+y,o="pre"+y,q="post"+y,t=y+"mode",h=y+"name",u="refresh",n="reset",z="";var k={FORM_NOT_FOUND:{},default_invalid_field_handler:function(B,C,A){if(!B[s]&&!C.disabled){this.set_focus(C);window.alert(A);B[s]=true;B[r]=true}},find:function(A){return document.getElementById(A)},register_form:function(B){var A=this[x](B);if(!A){this.FORM_NOT_FOUND[B]=true;return}A[b]=new d(A)},onpresubmit:function(C,A){var B=this[x](C);B[b][m+o+c](A)},onsubmit:function(B,A){this[x](B)[b][m+y+c](A)},onpostsubmit:function(B,A){this[x](B)[b][m+q+c](A)},onreset:function(B,A){this[x](B)[b][m+n+c](A)},onrefresh:function(B,A){this[x](B)[b][m+u+c](A)},oncancel:function(B,A){this[x](B)[b][m+e+c](A)},set_focus:function(A){if(typeof A==="string"){A=this[x](A);if(A){if(!A.disabled&&A.style.visibility!=="hidden"&&A.style.display!=="none"&&A.clientWidth>0){if(A.focus){A.focus()}if(A.isContentEditable||A.isContentEditable===undefined){if(A.select){A.select()}}}}}},trim_field_value:function(A){var B=this[x](A);B[i]=B[i].replace(/^\s+/g,"").replace(/\s+$/g,"")},require_field:function(C,A,B){var D=this[x](A);if(D[i].length===0){C.invalid_field(D,B)}},submit_form:function(A,B){this[x](A)[b][y](B)}};function v(C,B,A){this[l]=C;this.type=B;this[s]=false;this[r]=false;this[f]=A}v.prototype={invalid_field:function(B,A){this[f].call(k,this,B,A)},toString:function(){return"FormSubmitEvent["+this[l].name+" "+this.type+" "+this[s]+"]"}};function d(A){var B=this;B[l]=A;B.handlers={};A.onsubmit=function(){return A[b].onsubmit_handler()};A.onreset=function(){return A[b].onreset_handler()};B[f]=k.default_invalid_field_handler}d.prototype={add_handler:function(B,A){var C=this.handlers[B];if(!C){C=[];this.handlers[B]=C}C.push(A)},invoke_handlers:function(B,D){if(D[r]){return}var E=this.handlers[B];if(!E){return}var C=E.length,A=0;for(;A<C;A++){E[A].call(window,D);if(D[r]){return}}},add_cancel_handler:function(A){this[a](e,A)},cancel:function(){var C=this,B=C[l],A=new v(B,e,C[f]);C.invoke_handlers(e,A);if(A[s]===false){B[t][i]=e;B[w]=null;B[y]()}},add_presubmit_handler:function(A){this[a](o,A)},add_submit_handler:function(A){this[a](y,A)},add_postsubmit_handler:function(A){this[a](q,A)},submit:function(A){var C=this,B=C[l];if(C.onsubmit_handler()){B[w]=null;B[h][i]=A;B[y]()}},onsubmit_handler:function(){var C=this,B=C[l],A=new v(B,y,C[f]);C.invoke_handlers(o,A);C.invoke_handlers(y,A);C.invoke_handlers(q,A);if(A[s]){return false}B[t][i]=y;B[h][i]=z;return true},add_refresh_handler:function(A){this[a](y,A);this[a](u,A)},refresh:function(A){var D=this,C=D[l],B=new v(C,u,D[f]);D.invoke_handlers(u,B);if(B[s]){return}C[t][i]=u;C[h][i]=A;C[w]=null;C[y]()},add_reset_handler:function(A){this[a](n,A)},onreset_handler:function(){var B=this,A=new v(B[l],n,B[f]);B.invoke_handlers(n,A);return !A[s]}};this.Tapestry=k}());</script><script language="JavaScript" type="text/javascript"><!--
# if(!window.ZMOB_nativeAPI||(window.ZMOB_nativeAPI&&!window.ZMOB_nativeAPI.trackWebviewEvent)){(function(){window._gaq=window._gaq||[];window._gaqBackup=window._gaqBackup||[];window._gaq.push(["_setAccount","UA-21174015-1"]);window._gaq.push(["_setDomainName",".zillow.com"]);window._gaqBackup=[["_setCustomVar",6,"Zip",""],["_setCustomVar",8,"Address",""],["_setCustomVar",22,"AccountCreationDate","",1],["_setCustomVar",1,"Guid","666c37a240334183ad2a41da562008d8",1],["_setCustomVar",146,"RegionID","12700"],["_setCustomVar",66,"PageType","Search"],["_setCustomVar",5,"City","Miami"],["_setCustomVar",164,"A/B Test 26","NFSHDP_CLAIMS_UPSELL.VARIANT_D",1],["_setCustomVar",7,"Neighborhood",""],["_setCustomVar",25,"Device Type","Desktop"],["_setCustomVar",197,"searchListZpids","[43832660, 2077384999, 44183752, 70767374, 2066686741, 44167091, 43873395, 92439896, 92444011, 43862618, 44284115, 44225938, 44163090, 70772922, 43815737, 2075886382, 247651941, 43864622, 43871329, 43838866, 92436354, 43848535, 43829077, 247680925, 82416910, 44186226, 43813600, 2066585152, 248839403, 308907424, 70774248, 247650631, 43808498, 247653181, 44279554, 43843901, 43842032, 44189242, 162033257, 306397880]"],["_setCustomVar",166,"A/B Test 28","SXP_HDP_Load_Order.OPTIMIZED",1],["_setCustomVar",167,"A/B Test 29","ZXR_EXPERIMENT_AA_TEST.CONDITION_A",1],["_setCustomVar",92,"SEO Test 3","SEOTEST__RE_Add_BuildingOverview_SRP.CONTROL",1],["_setCustomVar",3,"State","FL"],["_setCustomVar",90,"SEO Test 1","SEOTEST__SRP_PAGINATION.ON",1],["_setCustomVar",23,"SearchTypes","ForSale",2],["_setCustomVar",12,"UserType","Unrecognized",2],["_setCustomVar",60,"A/B Test 20","VL_FACTS_AND_FEATURES_REDESIGN.TEST",1],["_setCustomVar",4,"County","Miami-Dade County"],["_setCustomVar",58,"A/B Test 18","HDP_SELLING_SOON_MSG.MOBILE_VARIANT_2",1],["_setCustomVar",59,"A/B Test 19","VL_HEADER_OPTIMIZATION.ON",1],["_setCustomVar",39,"A/B Test 14","ARCS_TOUR_UPGRADE_V1.ARCS_TOUR_UPGRADE_PLAIN",1],["_setCustomVar",40,"A/B Test 15","SXP_NONMLS_OFF.CONTROL",1],["_setCustomVar",56,"A/B Test 16","ARCS_PA_ZHL_LEAD.T1_OPAQUE_LIGHTBOX_ONLY_ABAD_ABC_ONLY",1],["_setCustomVar",57,"A/B Test 17","HDP_HFF_ACCORDION.CONTROL",1],["_setCustomVar",50,"A/B Test 10","ARCS_ABAD_PHX.ON",1],["_setCustomVar",36,"A/B Test 11","RE_RENTER_PROFILE_V3_REFRESH.AA_VARIANT",1],["_setCustomVar",37,"A/B Test 12","SET_COMPARE.ON",1],["_setCustomVar",38,"A/B Test 13","VL_EXPANDED_CONTENT.BUTTON",1],["_setCustomVar",158,"RegionTrialType","USER"],["_setCustomVar",70,"InternalSearchTerm","Miami, FL"],["_setCustomVar",182,"A/B Test 44","YOLT_NO_OB_TOURS_PHX.ON",1],["_setCustomVar",180,"A/B Test 42","ONSITE_MESSAGE_VALVE.OMP_ON",1],["_setCustomVar",159,"UserFirstVisitTrialTypes",""],["_setCustomVar",181,"A/B Test 43","YOLT_NO_OB_TOURS_ATL.CONTROL",1],["_setCustomVar",18,"SearchScenario","Region-City"],["_setCustomVar",187,"A/B Test 49","SPT_RENDER_FOR_SALE_PAGE.ON",1],["_setCustomVar",184,"A/B Test 46","NFSHDP_OWNER_OPTIONS_GOOGLE_AD.ON",1],["_setCustomVar",185,"A/B Test 47","AIPERS_COLLECTIONS_UPDATES_TAB.MODEL_C_1",1],["_setCustomVar",71,"SortType","globalrelevanceex"],["_setCustomVar",188,"A/B Test 50","ZEXP_DECISION_TOKEN_HOLD.l6vMnwVtjIUR",1],["_setCustomVar",69,"FullReferringURL",""],["_setCustomVar",49,"A/B Test 9","AR_BUYER_INITIATED_RELATIONSHIP_UI.CONTROL",1],["_setCustomVar",46,"A/B Test 6","AB_DASHBOARD_AA_TEST.CONTROL",1],["_setCustomVar",65,"A/B Test 25","ZO_FSHDP_RTBP.ON",1],["_setCustomVar",45,"A/B Test 5","VL_HDP_MODULE.MORE_UNITS",1],["_setCustomVar",42,"A/B Test 2","MIGHTY_MONTH_2022_HOLDOUT.MIGHTY_MONTH_ON",1],["_setCustomVar",61,"A/B Test 21","VL_FLOORPLAN_NAMES.ON",1],["_setCustomVar",41,"A/B Test 1","RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT_MULTIVARIATE.CONTROL",1],["_setCustomVar",62,"A/B Test 22","RE_SECOND_BOOST.SLOT_4",1],["_setCustomVar",44,"A/B Test 4","ARCS_CLICK_TO_CALL_TRACKING.CONTROL",1],["_setCustomVar",64,"A/B Test 24","DXP_RTB_LINKING.CONTROL",1],["_setCustomVar",68,"FullURL","https://www.zillow.c ...
# var _comscore=_comscore||[];_comscore.push({c1:2,c2:"6036206",c3:"",c4:"www.zillow.com/homes/for_sale/miami/10_p/",c5:"",c6:"",c15:""});var _comscoreBackup=_comscoreBackup||[];_comscoreBackup.push.apply(_comscoreBackup,_comscore);setTimeout(function(){var b=document.createElement("script");b.type="text/javascript";b.setAttribute("async",true);b.src=(document.location.protocol=="https:"?"https://sb":"http://b")+".scorecardresearch.com/beacon.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,a)},100);
#
# // --></script></body>
# </html><!-- H:028  T:227ms  S:559750  R:Sat Feb 12 12:50:12 PST 2022  B:5.0.68679-master.345eb64~qa.a4a41082 -->
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <module>
#     555 home_value = soup.select_one('h4:contains("Home value")')
#     556 if not home_value:
# --> 557     home_value = soup.select_one('.zestimate').text.split()[-1]
#     558 else:
#     559     home_value = home_value.find_next('p').get_text(strip=True)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext

#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

#add headers in case you use chromedriver (captchas are no fun); namely used for chromedriver
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

#create url variables for each zillow page
with requests.Session() as s:
    city = 'austin/' #*****change this city to what you want!!!!*****
    
    url = 'https://www.zillow.com/homes/for_sale/'+city
    url2 = 'https://www.zillow.com/homes/for_sale/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_sale/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_sale/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_sale/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_sale/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_sale/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_sale/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_sale/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_sale/'+city+'/10_p/'

    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

# page_links = [soup, soup1, soup2, soup3, soup4, soup5, soup6, soup7, soup8, soup9]

#create the first two dataframes
df = pd.DataFrame()
df1 = pd.DataFrame()

#all for loops are pulling the specified variable using beautiful soup and inserting into said variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
#     print(href)
    if href == None:
        addresses = None
#         addresses = 'zillow doesnt like this piece of code!'
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
#     print(addresses)
#     addresses = addresses.get_text()
#     addresses = href.find_all(href=True)
#     addresses = href.find('address class')
#     addresses.extract()
#     print(addresses)
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

df['links'] = urls
df['links'] = df['links'].astype('str')

#remove html tags
# df['links'] = df['links'].replace('<a class="list-card-link" href="', ' ', regex=True)
# df['links'] = df['links'].replace('" tabindex="0"></a>', ' ', regex=True)

for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup1.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup1.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup1.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup1.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup1.find_all (class_= 'list-card-link')
    zestimate1 = soup1.find_all (class_= 'Text-c11n-8-38-0__aiai24-0 jtMauM')

    #create dataframe columns out of variables
    df1['prices'] = price1
    df1['address'] = address1
    df1['beds'] = beds
    df1['zestimate'] = zestimate1

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df1['links'] = urls
df1['links'] = df1['links'].astype('str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <module>
#     134     df1['address'] = address1
#     135     df1['beds'] = beds
# --> 136     df1['zestimate'] = zestimate1
#     138 #create empty url list
#     139 urls = []
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:3656, in DataFrame.__setitem__(self, key, value)
#    3653     self._setitem_array([key], value)
#    3654 else:
#    3655     # set column
# -> 3656     self._set_item(key, value)
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:3833, in DataFrame._set_item(self, key, value)
#    3823 def _set_item(self, key, value) -> None:
#    3824     """
#    3825     Add series to DataFrame in specified column.
#    3826
#    (...)
#    3831     ensure homogeneity.
#    3832     """
# -> 3833     value = self._sanitize_column(value)
#    3835     if (
#    3836         key in self.columns
#    3837         and value.ndim == 1
#    3838         and not is_extension_array_dtype(value)
#    3839     ):
#    3840         # broadcast across multiple columns if necessary
#    3841         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:4537, in DataFrame._sanitize_column(self, value)
#    4534     return _reindex_for_setitem(value, self.index)
#    4536 if is_list_like(value):
# -> 4537     com.require_length_match(value, self.index)
#    4538 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File C:\Python39\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (0) does not match length of index (9)

# %%
for link in soup.find_all ('div', {'id': 'ds-home-values'}):
    print(link)
#     href = link.find('a',class_="list-card-link")
#     if href == None:
#         addresses = None
#     else:
#         addresses = href.find('address',class_="list-card-addr").get_text()
#     urls.append(addresses)
#     urls = [x for x in urls if x is not None]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 for link in soup.find_all ('div', {'id': 'ds-home-values'}):
#       2     print(link)
#
# NameError: name 'soup' is not defined
